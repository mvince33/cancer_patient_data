# %% [markdown]
# # Imports

# %%
# Imports
import numpy as np
import pandas as pd

# %% [markdown]
# # Load the Data

# %%
# Load the data
# Url for the data set: https://www.kaggle.com/datasets/thedevastator/cancer-patients-and-air-pollution-a-new-link
df = pd.read_csv('data/cancer_patient_data.csv')
df.head()
# Out:
#    index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0      0         P1   33       1              2            4             5
# 1      1        P10   17       1              3            1             5
# 2      2       P100   35       1              4            5             6
# 3      3      P1000   37       1              7            7             7
# 4      4       P101   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Fatigue  \
# 0                     4             3                     2  ...        3
# 1                     3             4                     2  ...        1
# 2                     5             5                     4  ...        8
# 3                     7             6                     7  ...        4
# 4                     7             7                     6  ...        3
#
# ...

# %% [markdown]
# # Data Cleaning

# %%
# Check for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# Check for missing values
df.isna().sum().sum()
# Out:
# 0

# %%
# Call the info method
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     1000 non-null   int64
#  1   Patient Id                1000 non-null   object
#  2   Age                       1000 non-null   int64
#  3   Gender                    1000 non-null   int64
#  4   Air Pollution             1000 non-null   int64
#  5   Alcohol use               1000 non-null   int64
#  6   Dust Allergy              1000 non-null   int64
#  7   OccuPational Hazards      1000 non-null   int64
#  8   Genetic Risk              1000 non-null   int64
#  9   chronic Lung Disease      1000 non-null   int64
#  10  Balanced Diet             1000 non-null   int64
#  11  Obesity                   1000 non-null   int64
#  12  Smoking                   1000 non-null   int64
#  13  Passive Smoker            1000 non-null   int64
# ...

# %%
df.select_dtypes(include = 'object')
# Out:
#     Patient Id   Level
# 0           P1     Low
# 1          P10  Medium
# 2         P100    High
# 3        P1000    High
# 4         P101    High
# ..         ...     ...
# 995       P995    High
# 996       P996    High
# 997       P997    High
# 998       P998    High
# 999       P999    High
#
# [1000 rows x 2 columns]

# %% [markdown]
# > Not sure what the "Level" column is referring to. This question was asked in the forum on Kaggle. Check back soon.
